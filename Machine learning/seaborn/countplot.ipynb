# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=sns.load_dataset('tips')
data=data.head(10)

# %%
sns.countplot(data,x='total_bill',hue='sex',width=.8)
plt.show()
