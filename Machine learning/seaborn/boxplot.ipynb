# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data=sns.load_dataset('tips')
data
sns.boxplot(data,x='day',y='tip',width=.8,showmeans=True,meanprops={'marker':'+','markeredgecolor':'b'},color='w')
plt.show()
